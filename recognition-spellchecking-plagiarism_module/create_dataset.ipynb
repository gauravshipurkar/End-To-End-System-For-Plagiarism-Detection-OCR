# %%
import os, shutil 
from pathlib import Path 

path = r"D:\Dataset"
count = 0
for f in os.listdir(path):
    file = 'D:\\Dataset\\'+str(f)
    file1 = Path("D:\\Small_Dataset\\"+str(f))
    
    if file1.exists():
        continue

    shutil.copy(file,"D:\\Small_Dataset\\")

    if count == 100:
        break
    else:
        count = count+1

# %%
import os
import shutil
from pathlib import Path
import cv2
from PIL import Image

path = r'D:\\Small_Dataset\\'
c=0
os.chdir('D:\Dataset_Roboflow')
for f in os.listdir(path):
    file = path + str(f)
    file1 = 'D:\Dataset_Roboflow' + str(f)
    print(file)
    img = cv2.imread(file, 1)
    img = cv2.resize(img, (1000, 1000))
    image = img[184:777, 83:995]
    cv2.imwrite(f, image)
    # cv2.imwrite(file,image)
# Out:
# D:\\Small_Dataset\\a01-000u.png
# D:\\Small_Dataset\\a01-000x.png
# D:\\Small_Dataset\\a01-003.png
# D:\\Small_Dataset\\a01-003u.png
# D:\\Small_Dataset\\a01-003x.png
# D:\\Small_Dataset\\a01-007.png
# D:\\Small_Dataset\\a01-007u.png
# D:\\Small_Dataset\\a01-007x.png
# D:\\Small_Dataset\\a01-011.png
# D:\\Small_Dataset\\a01-011u.png
# D:\\Small_Dataset\\a01-011x.png
# D:\\Small_Dataset\\a01-014.png
# D:\\Small_Dataset\\a01-014u.png
# D:\\Small_Dataset\\a01-014x.png
# D:\\Small_Dataset\\a01-020.png
# D:\\Small_Dataset\\a01-020u.png
# D:\\Small_Dataset\\a01-020x.png
# D:\\Small_Dataset\\a01-026.png
# D:\\Small_Dataset\\a01-026u.png
# D:\\Small_Dataset\\a01-026x.png
# D:\\Small_Dataset\\a01-030.png
# D:\\Small_Dataset\\a01-030u.png
# D:\\Small_Dataset\\a01-030x.png
# D:\\Small_Dataset\\a01-038.png
# D:\\Small_Dataset\\a01-038x.png
# D:\\Small_Dataset\\a01-043.png
# D:\\Small_Dataset\\a01-043u.png
# D:\\Small_Dataset\\a01-043x.png
# D:\\Small_Dataset\\a01-049.png
# ...

# %%
"D:\Dataset\a01-000u.png"
